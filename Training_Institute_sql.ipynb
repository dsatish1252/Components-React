# %% [markdown]
# <a href="https://colab.research.google.com/github/dsatish1252/Components-React/blob/main/Training_Institute_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
from pathlib import Path

conn = sqlite3.connect("training_academy.db")

# Enable Foreign Keys
conn.execute("PRAGMA foreign_keys = ON;")

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %%
def execute_query(sql, params=None):
    if params is None:
        params = ()

    cursor = conn.cursor()
    cursor.execute(sql, params)
    conn.commit()


def read_query(sql):
    return pd.read_sql_query(sql, conn)

# %%
create_departments = """
CREATE TABLE IF NOT EXISTS departments(

department_id INTEGER PRIMARY KEY,

department_name TEXT NOT NULL UNIQUE

);
"""

execute_query(create_departments)

print("Departments Table Created")
# Out:
# Departments Table Created

# %%
read_query("SELECT * FROM departments")
# Out:
# Empty DataFrame
# Columns: [department_id, department_name]
# Index: []

# %%
departments = [

(1,"Data Science"),
(2,"Software Engineering"),
(3,"Business Analytics"),
(4,"SAP BTP"),
(5,"Java FS + GenAI")

]

conn.executemany(
    "INSERT INTO departments VALUES (?,?)",
    departments
)

conn.commit()

print("Departments Inserted")
# Out:
# Departments Inserted

# %%
read_query("SELECT * FROM departments")
# Out:
#    department_id       department_name
# 0              1          Data Science
# 1              2  Software Engineering
# 2              3    Business Analytics
# 3              4               SAP BTP
# 4              5       Java FS + GenAI

# %%
conn.commit()

# %%
create_students = """
CREATE TABLE IF NOT EXISTS students (

    student_id INTEGER PRIMARY KEY,
    student_name TEXT NOT NULL,
    email TEXT NOT NULL UNIQUE,
    city TEXT,
    registration_date DATE NOT NULL

);
"""

execute_query(create_students)
print("Students table created successfully.")
# Out:
# Students table created successfully.

# %%
create_instructors = """
CREATE TABLE IF NOT EXISTS instructors (

    instructor_id INTEGER PRIMARY KEY,
    instructor_name TEXT NOT NULL,
    email TEXT NOT NULL UNIQUE,
    department_id INTEGER,

    FOREIGN KEY(department_id)
        REFERENCES departments(department_id)

);
"""

execute_query(create_instructors)
print("Instructors table created successfully.")
# Out:
# Instructors table created successfully.

# %%
create_courses = """
CREATE TABLE IF NOT EXISTS courses (

    course_id INTEGER PRIMARY KEY,
    course_name TEXT NOT NULL,
    department_id INTEGER,
    instructor_id INTEGER,
    fee REAL NOT NULL CHECK(fee >= 0),
    level TEXT CHECK(level IN ('Beginner','Intermediate','Advanced')),

    FOREIGN KEY(department_id)
        REFERENCES departments(department_id),

    FOREIGN KEY(instructor_id)
        REFERENCES instructors(instructor_id)

);
"""

execute_query(create_courses)
print("Courses table created successfully.")
# Out:
# Courses table created successfully.

# %%
create_enrollments = """
CREATE TABLE IF NOT EXISTS enrollments (

    enrollment_id INTEGER PRIMARY KEY,
    student_id INTEGER,
    course_id INTEGER,
    enrollment_date DATE NOT NULL,
    status TEXT DEFAULT 'Active'
        CHECK(status IN ('Active','Completed','Cancelled')),

    FOREIGN KEY(student_id)
        REFERENCES students(student_id),

    FOREIGN KEY(course_id)
        REFERENCES courses(course_id),

    UNIQUE(student_id, course_id)

);
"""

execute_query(create_enrollments)
print("Enrollments table created successfully.")
# Out:
# Enrollments table created successfully.

# %%
create_payments = """
CREATE TABLE IF NOT EXISTS payments (

    payment_id INTEGER PRIMARY KEY,
    enrollment_id INTEGER UNIQUE,
    amount REAL NOT NULL CHECK(amount >= 0),
    payment_date DATE NOT NULL,
    payment_status TEXT
        CHECK(payment_status IN ('Paid','Pending','Refunded')),

    FOREIGN KEY(enrollment_id)
        REFERENCES enrollments(enrollment_id)

);
"""

execute_query(create_payments)
print("Payments table created successfully.")
# Out:
# Payments table created successfully.

# %%
tables = read_query("""
SELECT name
FROM sqlite_master
WHERE type='table';
""")

tables
# Out:
#           name
# 0  departments
# 1     students
# 2  instructors
# 3      courses
# 4  enrollments
# 5     payments

# %%
students = [
    (1, "Rahul Kumar", "rahul.kumar@example.com", "Patna", "2026-01-05"),
    (2, "Priya Singh", "priya.singh@example.com", "Kolkata", "2026-01-06"),
    (3, "Amit Raj", "amit.raj@example.com", "Delhi", "2026-01-07"),
    (4, "Sneha Verma", "sneha.verma@example.com", "Patna", "2026-01-10"),
    (5, "Aditya Sharma", "aditya.sharma@example.com", "Mumbai", "2026-01-12")
]

conn.executemany(
    "INSERT INTO students VALUES (?, ?, ?, ?, ?)",
    students
)
conn.commit()

# %%
instructors = [
    (1, "Dr. Meera Iyer", "meera.iyer@example.com", 1),
    (2, "Arjun Sen", "arjun.sen@example.com", 2),
    (3, "Kavita Rao", "kavita.rao@example.com", 3)
]

conn.executemany(
    "INSERT INTO instructors VALUES (?, ?, ?, ?)",
    instructors
)
conn.commit()

# %%
courses = [
    (101, "Python for Beginners", 2, 2, 4999, "Beginner"),
    (102, "SQL and RDBMS Masterclass", 1, 1, 6999, "Beginner"),
    (103, "Machine Learning Basics", 1, 1, 11999, "Intermediate"),
    (104, "Business Dashboarding", 3, 3, 8999, "Intermediate"),
    (105, "Advanced Data Engineering", 1, 1, 15999, "Advanced")
]

conn.executemany(
    "INSERT INTO courses VALUES (?, ?, ?, ?, ?, ?)",
    courses
)
conn.commit()

# %%
enrollments = [
    (1001, 1, 101, "2026-02-01", "Active"),
    (1002, 1, 102, "2026-02-03", "Completed"),
    (1003, 2, 102, "2026-02-04", "Active"),
    (1004, 3, 103, "2026-02-05", "Active"),
    (1005, 4, 104, "2026-02-07", "Cancelled")
]

conn.executemany(
    "INSERT INTO enrollments VALUES (?, ?, ?, ?, ?)",
    enrollments
)
conn.commit()

# %%
payments = [
    (501, 1001, 4999, "2026-02-01", "Paid"),
    (502, 1002, 6999, "2026-02-03", "Paid"),
    (503, 1003, 6999, "2026-02-04", "Pending"),
    (504, 1004, 11999, "2026-02-05", "Paid"),
    (505, 1005, 0, "2026-02-07", "Refunded")
]

conn.executemany(
    "INSERT INTO payments VALUES (?, ?, ?, ?, ?)",
    payments
)
conn.commit()

# %%
print("Departments")
display(read_query("SELECT * FROM departments"))

print("Students")
display(read_query("SELECT * FROM students"))

print("Instructors")
display(read_query("SELECT * FROM instructors"))

print("Courses")
display(read_query("SELECT * FROM courses"))

print("Enrollments")
display(read_query("SELECT * FROM enrollments"))

print("Payments")
display(read_query("SELECT * FROM payments"))
# Out:
# Departments
#    department_id       department_name
# 0              1          Data Science
# 1              2  Software Engineering
# 2              3    Business Analytics
# 3              4               SAP BTP
# 4              5       Java FS + GenAI
# Students
#    student_id   student_name                      email     city  \
# 0           1    Rahul Kumar    rahul.kumar@example.com    Patna
# 1           2    Priya Singh    priya.singh@example.com  Kolkata
# 2           3       Amit Raj       amit.raj@example.com    Delhi
# 3           4    Sneha Verma    sneha.verma@example.com    Patna
# 4           5  Aditya Sharma  aditya.sharma@example.com   Mumbai
#
#   registration_date
# 0        2026-01-05
# 1        2026-01-06
# 2        2026-01-07
# 3        2026-01-10
# 4        2026-01-12
# Instructors
#    instructor_id instructor_name                   email  department_id
# 0              1  Dr. Meera Iyer  meera.iyer@example.com              1
# ...

# %%
print("Departments")
display(read_query("SELECT * FROM departments"))
# Out:
# Departments
#    department_id       department_name
# 0              1          Data Science
# 1              2  Software Engineering
# 2              3    Business Analytics

# %%
delete_query = "DELETE FROM departments WHERE department_id = ?"

execute_query(delete_query, (4,))

print("Department deleted successfully.")

delete_query = "DELETE FROM departments WHERE department_id = ?"

execute_query(delete_query, (5,))

print("Department deleted successfully.")
# Out:
# Department deleted successfully.
# Department deleted successfully.

# %%
insert_student = """
INSERT INTO students (student_name, email, city, registration_date)
VALUES (?, ?, ?, ?)
"""

student_data = (
    "Rohan Das",
    "rohan.das@example.com",
    "Pune",
    "2026-02-15"
)

execute_query(insert_student, student_data)

print("New student inserted successfully.")
# Out:
# New student inserted successfully.

# %%
display(
    read_query("""
    SELECT *
    FROM students
    WHERE email = 'rohan.das@example.com'
    """)
)
# Out:
#    student_id student_name                  email       city registration_date
# 0           6    Rohan Das  rohan.das@example.com  Bengaluru        2026-02-15

# %%
update_query = """
UPDATE students
SET city = ?
WHERE student_id = ?
"""

execute_query(
    update_query,
    ("Bengaluru", 6)
)

print("Student city updated successfully.")
# Out:
# Student city updated successfully.

# %%
delete_query = """
DELETE FROM students
WHERE student_id = ?
"""

execute_query(delete_query, (6,))

print("Student deleted successfully.")
# Out:
# Student deleted successfully.

# %%
display(read_query("SELECT * FROM students"))
# Out:
#    student_id   student_name                      email     city  \
# 0           1    Rahul Kumar    rahul.kumar@example.com    Patna
# 1           2    Priya Singh    priya.singh@example.com  Kolkata
# 2           3       Amit Raj       amit.raj@example.com    Delhi
# 3           4    Sneha Verma    sneha.verma@example.com    Patna
# 4           5  Aditya Sharma  aditya.sharma@example.com   Mumbai
#
#   registration_date
# 0        2026-01-05
# 1        2026-01-06
# 2        2026-01-07
# 3        2026-01-10
# 4        2026-01-12

# %%
# Delete the student's enrollments
execute_query(
    "DELETE FROM enrollments WHERE student_id = ?",
    (6,)  # Replace 6 with the actual student_id
)

# Now delete the student
execute_query(
    "DELETE FROM students WHERE student_id = ?",
    (6,)
)

print("Student deleted successfully.")
# Out:
# Student deleted successfully.

# %%
try:
    execute_query("""
    INSERT INTO students (student_name, email, city, registration_date)
    VALUES (?, ?, ?, ?)
    """, (
        "Test Student",
        "rahul.kumar@example.com",  # Email already exists
        "Hyderabad",
        "2026-03-01"
    ))

except Exception as e:
    print("UNIQUE Constraint Error:")
    print(e)
# Out:
# UNIQUE Constraint Error:
# UNIQUE constraint failed: students.email

# %%
try:
    execute_query("""
    INSERT INTO enrollments
    (enrollment_id, student_id, course_id, enrollment_date, status)
    VALUES (?, ?, ?, ?, ?)
    """, (
        2001,
        999,              # Student ID does not exist
        101,
        "2026-03-01",
        "Active"
    ))

except Exception as e:
    print("FOREIGN KEY Constraint Error:")
    print(e)
# Out:
# FOREIGN KEY Constraint Error:
# FOREIGN KEY constraint failed

# %%
try:
    execute_query("""
    INSERT INTO courses
    (course_id, course_name, department_id, instructor_id, fee, level)
    VALUES (?, ?, ?, ?, ?, ?)
    """, (
        106,
        "Invalid Course",
        1,
        1,
        -5000,           # Negative fee
        "Beginner"
    ))

except Exception as e:
    print("CHECK Constraint Error:")
    print(e)
# Out:
# CHECK Constraint Error:
# CHECK constraint failed: fee >= 0

# %%
try:
    execute_query("""
    INSERT INTO enrollments
    (enrollment_id, student_id, course_id, enrollment_date, status)
    VALUES (?, ?, ?, ?, ?)
    """, (
        2002,
        1,
        103,
        "2026-03-01",
        "Started"         # Invalid status
    ))

except Exception as e:
    print("CHECK Constraint Error:")
    print(e)
# Out:
# CHECK Constraint Error:
# CHECK constraint failed: status IN ('Active','Completed','Cancelled')

# %%
print("Students Table Schema")
display(read_query("PRAGMA table_info(students);"))
# Out:
# Students Table Schema
#    cid               name     type  notnull dflt_value  pk
# 0    0         student_id  INTEGER        0       None   1
# 1    1       student_name     TEXT        1       None   0
# 2    2              email     TEXT        1       None   0
# 3    3               city     TEXT        0       None   0
# 4    4  registration_date     DATE        1       None   0

# %%
# Table Schemas
tables = ["students", "courses", "enrollments", "payments"]

for table in tables:
    print(f"\n===== {table.upper()} TABLE SCHEMA =====")
    display(read_query(f"PRAGMA table_info({table});"))

# Foreign Keys
fk_tables = ["instructors", "courses", "enrollments", "payments"]

for table in fk_tables:
    print(f"\n===== FOREIGN KEYS OF {table.upper()} =====")
    display(read_query(f"PRAGMA foreign_key_list({table});"))
# Out:
# ===== STUDENTS TABLE SCHEMA =====
#    cid               name     type  notnull dflt_value  pk
# 0    0         student_id  INTEGER        0       None   1
# 1    1       student_name     TEXT        1       None   0
# 2    2              email     TEXT        1       None   0
# 3    3               city     TEXT        0       None   0
# 4    4  registration_date     DATE        1       None   0
# ===== COURSES TABLE SCHEMA =====
#    cid           name     type  notnull dflt_value  pk
# 0    0      course_id  INTEGER        0       None   1
# 1    1    course_name     TEXT        1       None   0
# 2    2  department_id  INTEGER        0       None   0
# 3    3  instructor_id  INTEGER        0       None   0
# 4    4            fee     REAL        1       None   0
# 5    5          level     TEXT        0       None   0
# ===== ENROLLMENTS TABLE SCHEMA =====
#    cid             name     type  notnull dflt_value  pk
# 0    0    enrollment_id  INTEGER        0       None   1
# ...

# %%
display(read_query("""
SELECT *
FROM students;
"""))
# Out:
#    student_id   student_name                      email     city  \
# 0           1    Rahul Kumar    rahul.kumar@example.com    Patna
# 1           2    Priya Singh    priya.singh@example.com  Kolkata
# 2           3       Amit Raj       amit.raj@example.com    Delhi
# 3           4    Sneha Verma    sneha.verma@example.com    Patna
# 4           5  Aditya Sharma  aditya.sharma@example.com   Mumbai
#
#   registration_date
# 0        2026-01-05
# 1        2026-01-06
# 2        2026-01-07
# 3        2026-01-10
# 4        2026-01-12

# %%
display(read_query("""
SELECT *
FROM students
WHERE city = 'Patna';
"""))
# Out:
#    student_id student_name                    email   city registration_date
# 0           1  Rahul Kumar  rahul.kumar@example.com  Patna        2026-01-05
# 1           4  Sneha Verma  sneha.verma@example.com  Patna        2026-01-10

# %%
display(read_query("""
SELECT *
FROM courses
WHERE fee > 7000;
"""))
# Out:
#    course_id                course_name  department_id  instructor_id  \
# 0        103    Machine Learning Basics              1              1
# 1        104      Business Dashboarding              3              3
# 2        105  Advanced Data Engineering              1              1
#
#        fee         level
# 0  11999.0  Intermediate
# 1   8999.0  Intermediate
# 2  15999.0      Advanced

# %%
display(read_query("""
SELECT *
FROM courses
WHERE level = 'Beginner';
"""))
# Out:
#    course_id                course_name  department_id  instructor_id     fee  \
# 0        101       Python for Beginners              2              2  4999.0
# 1        102  SQL and RDBMS Masterclass              1              1  6999.0
#
#       level
# 0  Beginner
# 1  Beginner

# %%
display(read_query("""
SELECT *
FROM students
ORDER BY student_name ASC;
"""))
# Out:
#    student_id   student_name                      email     city  \
# 0           5  Aditya Sharma  aditya.sharma@example.com   Mumbai
# 1           3       Amit Raj       amit.raj@example.com    Delhi
# 2           2    Priya Singh    priya.singh@example.com  Kolkata
# 3           1    Rahul Kumar    rahul.kumar@example.com    Patna
# 4           4    Sneha Verma    sneha.verma@example.com    Patna
#
#   registration_date
# 0        2026-01-12
# 1        2026-01-07
# 2        2026-01-06
# 3        2026-01-05
# 4        2026-01-10

# %%
display(read_query("""
SELECT course_name, fee
FROM courses
ORDER BY fee DESC
LIMIT 3;
"""))
# Out:
#                  course_name      fee
# 0  Advanced Data Engineering  15999.0
# 1    Machine Learning Basics  11999.0
# 2      Business Dashboarding   8999.0

# %%
display(read_query("""
SELECT DISTINCT city
FROM students;
"""))
# Out:
#       city
# 0    Patna
# 1  Kolkata
# 2    Delhi
# 3   Mumbai

# %%
display(read_query("""
SELECT *
FROM payments
WHERE payment_status = 'Pending';
"""))
# Out:
#    payment_id  enrollment_id  amount payment_date payment_status
# 0         503           1003  6999.0   2026-02-04        Pending

# %%
display(read_query("""
SELECT
    c.course_name,
    i.instructor_name,
    c.fee,
    c.level
FROM courses c
JOIN instructors i
ON c.instructor_id = i.instructor_id;
"""))
# Out:
#                  course_name instructor_name      fee         level
# 0       Python for Beginners       Arjun Sen   4999.0      Beginner
# 1  SQL and RDBMS Masterclass  Dr. Meera Iyer   6999.0      Beginner
# 2    Machine Learning Basics  Dr. Meera Iyer  11999.0  Intermediate
# 3      Business Dashboarding      Kavita Rao   8999.0  Intermediate
# 4  Advanced Data Engineering  Dr. Meera Iyer  15999.0      Advanced

# %%
display(read_query("""
SELECT
    s.student_name,
    c.course_name,
    e.status
FROM enrollments e
JOIN students s
ON e.student_id = s.student_id
JOIN courses c
ON e.course_id = c.course_id;
"""))
# Out:
#   student_name                course_name     status
# 0  Rahul Kumar       Python for Beginners     Active
# 1  Rahul Kumar  SQL and RDBMS Masterclass  Completed
# 2  Priya Singh  SQL and RDBMS Masterclass     Active
# 3     Amit Raj    Machine Learning Basics     Active
# 4  Sneha Verma      Business Dashboarding  Cancelled

# %%
display(read_query("""
SELECT
    s.student_name,
    c.course_name,
    p.amount,
    p.payment_status
FROM payments p
JOIN enrollments e
ON p.enrollment_id = e.enrollment_id
JOIN students s
ON e.student_id = s.student_id
JOIN courses c
ON e.course_id = c.course_id;
"""))
# Out:
#   student_name                course_name   amount payment_status
# 0  Rahul Kumar       Python for Beginners   4999.0           Paid
# 1  Rahul Kumar  SQL and RDBMS Masterclass   6999.0           Paid
# 2  Priya Singh  SQL and RDBMS Masterclass   6999.0        Pending
# 3     Amit Raj    Machine Learning Basics  11999.0           Paid
# 4  Sneha Verma      Business Dashboarding      0.0       Refunded
